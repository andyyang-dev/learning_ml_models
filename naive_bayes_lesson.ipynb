# %% [markdown]
# # Naive Bayes

# %%
from typing import List, Dict
from enum import Enum
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import generate_random_data

# %%
class GirlType(Enum):
    WIFEY_MATERIAL = "Wifey Material"
    PROFESSIONAL_PARTNER = "Professional Partner"
    SEXUALLY_ENTICING = "Sexually Enticing"
    STRANGER = "Stranger"

# %%
df = generate_random_data.get_naive_bayes_data(1250)
df = df.sample(frac=1).reset_index(drop=True)
df.sample(10)
# Out:
#      Facial Attractiveness Body Attractiveness Professional Scale  \
# 1221             Beautiful              Normal       Professional
# 958                    Mid                 Hot       Professional
# 375                   Ugly           Not Ideal       Professional
# 1197                   Mid                 Hot       Professional
# 285                    Mid           Not Ideal       Professional
# 704              Beautiful                 Hot   Not Professional
# 1188                   Mid              Normal       Professional
# 857                   Ugly           Not Ideal       Professional
# 629                    Mid           Not Ideal   Not Professional
# 509              Beautiful              Normal       Professional
#
#      Feminime Energy Scale Attitude Scale             Girl Type
# 1221             Masculine           Nice  Professional Partner
# 958               Feminime           Nice  Professional Partner
# 375               Feminime         Normal              Stranger
# 1197             Masculine           Nice  Professional Partner
# 285              Masculine           Nice  Professional Partner
# 704               Feminime         Normal     Sexually Enticing
# 1188             Masculine           Nice  Professional Partner
# 857              Masculine       Not Nice              Stranger
# 629               Feminime         Normal              Stranger
# 509               Feminime           Nice        Wifey Material

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

X = df[df.columns[:-1]]
y = df[df.columns[-1]]
X_encoder = OrdinalEncoder()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

sklearn_model = CategoricalNB()
sklearn_model.fit(X_encoder.fit_transform(X_train), y_train)

y_predict = sklearn_model.predict(X_encoder.fit_transform(X_test))
sum(y_test == y_predict) / len(y_test)
# Out:
# 0.94

# %%
from collections import defaultdict
import math

class MyCategoricalNB:
    def __init__(self):
        self.n_dataset = 0
        self.feature_category_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: 1))) 
        self.class_counts = defaultdict(lambda: 1)
        self.p_Xvalue_given_c = defaultdict(int)

    def fit(self, X, y):
        y = y.reset_index(drop=True)
        self.n_dataset = len(y)
        for i in range(self.n_dataset):
            for j, Xj in enumerate(X[i]):
                self.feature_category_counts[y[i]][j][Xj] += 1
            self.class_counts[y[i]] += 1
    
    def predict(self, X_test):
        y_predictions = []
        for X in X_test:
            for girl_type, features in self.feature_category_counts.items():
                for Xj, Xji in enumerate(X):
                    self.p_Xvalue_given_c[girl_type] += math.log(features[Xj][Xji] / self.class_counts[girl_type])
                self.p_Xvalue_given_c[girl_type] += math.log(self.class_counts[girl_type] / (self.n_dataset + len(self.class_counts)))
            prediction = max(self.p_Xvalue_given_c, key=self.p_Xvalue_given_c.get)
            y_predictions.append(prediction)
            self.p_Xvalue_given_c.clear()
        return y_predictions
    

my_model = MyCategoricalNB()
my_model.fit(X_encoder.fit_transform(X_train), y_train)
y_predict = my_model.predict(X_encoder.fit_transform(X_test))
print(sum(y_test == y_predict) / len(y_test), "Accuracy")
wrong_class_idx = y_test != y_predict 
wrong_class = X_test[wrong_class_idx]
wrong_class["Actual Girl Type"] = y_test[wrong_class_idx]
wrong_class["Predicted Girl Type"] = pd.Series(y_predict, index=wrong_class_idx.index).loc[wrong_class_idx]
wrong_class.sort_values("Actual Girl Type")
# Out:
# 0.94 Accuracy
# /var/folders/48/_n6x3sr95hs3x66w52bj3krw0000gn/T/ipykernel_2790/644059731.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrong_class["Actual Girl Type"] = y_test[wrong_class_idx]
# /var/folders/48/_n6x3sr95hs3x66w52bj3krw0000gn/T/ipykernel_2790/644059731.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrong_class["Predicted Girl Type"] = pd.Series(y_predict, index=wrong_class_idx.index).loc[wrong_class_idx]
#      Facial Attractiveness Body Attractiveness Professional Scale  \
# 107                    Mid                 Hot       Professional
# 530                    Mid                 Hot       Professional
# 286              Beautiful                 Hot   Not Professional
# 620              Beautiful              Normal   Not Professional
# 38               Beautiful                 Hot       Professional
# 779              Beautiful                 Hot   Not Professional
# 432              Beautiful                 Hot   Not Professional
# 1176             Beautiful                 Hot       Professional
# 628                    Mid                 Hot       Professional
# 935                   Ugly              Normal       Professional
# 177                   Ugly              Normal       Professional
# 1085             Beautiful              Normal       Professional
# 170                    Mid              Normal       Professional
# 1153             Beautiful                 Hot   Not Professional
# 679                    Mid                 Hot       Professional
#
#      Feminime Energy Scale Attitude Scale      Actual Girl Type  \
# 107               Feminime           Nice  Professional Partner
# 530               Feminime         Normal  Professional Partner
# 286               Feminime           Nice     Sexually Enticing
# 620              Masculine           Nice     Sexually Enticing
# 38                Feminime           Nice     Sexually Enticing
# 779               Feminime           Nice     Sexually Enticing
# 432               Feminime           Nice     Sexually Enticing
# 1176              Feminime           Nice     Sexually Enticing
# 628               Feminime           Nice     Sexually Enticing
# 935               Feminime         Normal              Stranger
# 177               Feminime         Normal              Stranger
# 1085             Masculine           Nice        Wifey Material
# 170               Feminime           Nice        Wifey Material
# 1153             Masculine           Nice        Wifey Material
# 679              Masculine           Nice        Wifey Material
#
#        Predicted Girl Type
# 107         Wifey Material
# 530      Sexually Enticing
# 286         Wifey Material
# 620         Wifey Material
# 38          Wifey Material
# 779         Wifey Material
# 432         Wifey Material
# 1176        Wifey Material
# 628         Wifey Material
# 935   Professional Partner
# 177   Professional Partner
# 1085  Professional Partner
# 170   Professional Partner
# 1153     Sexually Enticing
# 679   Professional Partner
